# %% [markdown]
# ![LIKERT](data/imagens/crisp_dm.png)

# %% [markdown]
# #### Importações de bibliotecas, módulos, métodos...

# %%
# Álgebra linear, matrizes...
import numpy as np

# Manipulação de dados em tabela
import pandas as pd

# Visualização gráfica e plotagens - simples/"personalizadas"
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Avisos
import warnings

# %% [markdown]
# #### Configurações gerais

# %%
# Gráficos intra-celulares
# %matplotlib inline

# Tamanho dos gráficos (polegadas) - Proporção Áurea
mpl.rcParams['figure.figsize'] = 16.18, 10.00
sns.set(rc={'figure.figsize': (16.18, 10.00)})

# Opções para melhor visualização dos dados
pd.set_option('display.max_rows', None) # Linhas Máx   
pd.set_option('display.max_columns', None) # Colunas Máx
pd.set_option('display.max_colwidth', None) # Largura Cols
pd.set_option('display.width', None)  # Largura
pd.set_option('display.float_format', '{:.2f}'.format) # 2 casas decimais

# Ignorar avisos
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Carregar o banco de dados

# %% [markdown]
# ![LIKERT](data/imagens/dicionario_dados_amazon.png)

# %% [markdown]
# #### * Mindmap com possíveis variáveis que resolvem o problema.

# %% [markdown]
# ![LIKERT](data/imagens/variaveis_amazon.png)

# %%
# Carregar arquivo csv em formato de tabela
df = pd.read_csv('data/input_data/data.csv', delimiter=';')

# %%
# Visualizar as 25 primeias linhas e as últimas 10
display(df.head(25))
display(df.tail(10))
# Out:
#    Company            TypeName  Ram  Weight  Touchscreen  Price  Ips    ppi  \
# 0    Apple           Ultrabook    8    1.37            0   5491    1 226.98
# 1    Apple           Ultrabook    8    1.34            0   3684    0 127.68
# 2       HP            Notebook    8    1.86            0   2357    0 141.21
# 3    Apple           Ultrabook   16    1.83            0  10400    1 220.53
# 4    Apple           Ultrabook    8    1.37            0   7392    1 226.98
# 5     Acer            Notebook    4    2.10            0   1639    0 100.45
# 6    Apple           Ultrabook   16    2.04            0   8771    1 220.53
# 7    Apple           Ultrabook    8    1.34            0   4749    0 127.68
# 8     Asus           Ultrabook   16    1.30            0   6127    0 157.35
# 9     Acer           Ultrabook    8    1.60            0   3156    1 157.35
# 10      HP            Notebook    4    1.86            0   1614    0 100.45
# 11      HP            Notebook    4    1.86            0   1414    0 141.21
# 12   Apple           Ultrabook   16    1.83            0  10000    1 220.53
# 13    Dell            Notebook    4    2.20            0   2045    0 141.21
# 14   Apple           Ultrabook    8    0.92            0   5174    1 226.42
# 15   Apple           Ultrabook    8    1.37            0   6224    1 226.98
# 16    Dell            Notebook    8    2.20            0   3053    0 141.21
# 17   Apple           Ultrabook   16    1.83            0  11713    1 220.53
# 18  Lenovo            Notebook    8    2.20            0   2045    0 141.21
# 19    Dell           Ultrabook    8    1.22            1   4012    1 165.63
# 20    Asus             Netbook    2    0.98            0    786    0 135.09
# 21  Lenovo              Gaming    8    2.50            0   4094    1 141.21
# 22      HP            Notebook    4    1.86            0   1057    0 100.45
# 23    Dell  2 in 1 Convertible    8    1.62            1   3357    0 165.63
# 24      HP           Ultrabook    8    1.91            0   2701    0 141.21
#
#                 Cpu_brand   HDD  SSD Gpu_brand                  os
# 0           Intel Core i5     0  128     Intel                 Mac
# 1           Intel Core i5     0    0     Intel                 Mac
# 2           Intel Core i5     0  256     Intel  Others/No OS/Linux
# 3           Intel Core i7     0  512       AMD                 Mac
# 4           Intel Core i5     0  256     Intel                 Mac
# 5           AMD Processor   500    0       AMD             Windows
# 6           Intel Core i7     0    0     Intel                 Mac
# 7           Intel Core i5     0    0     Intel                 Mac
# 8           Intel Core i7     0  512    Nvidia             Windows
# 9           Intel Core i5     0  256     Intel             Windows
# 10          Intel Core i5   500    0     Intel  Others/No OS/Linux
# 11          Intel Core i3   500    0     Intel  Others/No OS/Linux
# 12          Intel Core i7     0  256       AMD                 Mac
# 13          Intel Core i3     0  256       AMD             Windows
# 14  Other Intel Processor     0  256     Intel                 Mac
# 15          Intel Core i5     0  256     Intel                 Mac
# 16          Intel Core i7     0  256       AMD             Windows
# 17          Intel Core i7     0  512       AMD                 Mac
# 18          Intel Core i3  1000    0    Nvidia  Others/No OS/Linux
# 19          Intel Core i5     0  128     Intel             Windows
# 20  Other Intel Processor     0    0     Intel             Windows
# 21          Intel Core i5     0  128    Nvidia             Windows
# 22          AMD Processor   500    0       AMD  Others/No OS/Linux
# 23          Intel Core i5     0  256     Intel             Windows
# 24          Intel Core i7     0  256     Intel             Windows
#      Company            TypeName  Ram  Weight  Touchscreen  Price  Ips    ppi  \
# 1292  Lenovo            Notebook    8    2.60            0   3685    1 141.21
# 1293      HP            Notebook    6    2.04            0   2254    0 141.21
# 1294    Dell            Notebook    8    2.30            0   3303    0 100.45
# 1295      HP             Netbook    2    1.17            0    857    0 135.09
# 1296    Asus            Notebook    4    2.20            0   2952    0 100.45
# 1297  Lenovo  2 in 1 Convertible    4    1.80            1   2615    1 157.35
# 1298  Lenovo  2 in 1 Convertible   16    1.30            1   6144    1 276.05
# 1299  Lenovo            Notebook    2    1.50            0    939    0 111.94
# 1300      HP            Notebook    6    2.19            0   3131    0 100.45
# 1301    Asus            Notebook    4    2.20            0   1512    0 100.45
#
#                   Cpu_brand   HDD  SSD Gpu_brand                  os
# 1292          Intel Core i7  1000    0    Nvidia             Windows
# 1293          AMD Processor     0    0       AMD             Windows
# 1294          Intel Core i7  1000    0       AMD  Others/No OS/Linux
# 1295  Other Intel Processor     0    0     Intel             Windows
# 1296          Intel Core i7   500    0    Nvidia             Windows
# 1297          Intel Core i7     0  128     Intel             Windows
# 1298          Intel Core i7     0  512     Intel             Windows
# 1299  Other Intel Processor     0    0     Intel             Windows
# 1300          Intel Core i7  1000    0       AMD             Windows
# 1301  Other Intel Processor   500    0     Intel             Windows

# %% [markdown]
# #### **Classificar atributos e instâncias**
#
# - **Numéricos**
#     * Dados representados por números e que possuem alguma medição envolvida - um é maior que outro.
#     * Também chamados de dados **quantitativos** em estatísticas.
#     * Exemplos:
#         - Idade,
#         - Altura,
#         - Peso,
#         - Temperatura,
#         - Pressão,
#         - Batimentos cardíacos...
#     * São divididos em **discretos** ou **contínuos**
#         - **discretos**
#             * Possuem limite definido.
#             * Podem ser contados.
#             * Seus valores podem ser listados.
#             * Exemplos:
#                 - Em 100 partidas de cara-coroa, o número de possibilidades para pontuar coroa varia entre 0 e 100.
#                 - O ranking de futebol da fifa possui números definidos entre 1, 2, 3, 4, 5...
#                 - A variável discreta "Países da América do Sul" pode conter os valores Brasil, Argentina, Chile...
#                 - ... "numéricos" pois Brasil-1, Argentina-2, Chile-3, ou vice-verca.
#
#         - **contínuos**
#             * Podem ter "infinitos" valores dentro de um valor definido.
#             * Podem seguir um medida de intervalo de escala ou medida de proporção de escala.
#
# - **Categóricos**
#     * Dados que representam as características de algum objeto-evento.
#     * Também chamados de dados **qualitativos** em estatísticas.
#     * Variáveis categóricas possuem *um* valor dentro de valores limitados pré-definidos
#     * Exemplos:
#         - Gênero, (Feminino, Masculino, Outro, Desconhecido...)
#         - Estado civil, (Solteiro(a), Casado(a), Divorciado(a), Viúvo(a)...)
#         - Tipo de residência (Apartamento, Casa, Kitnet...),
#         - Categoria de filmes...
#      * São divididos em **Binárias** ou **Múltiplas Classes**
#         - **Binárias (Dicotômicas)**
#             - Verdadeiro/Falso, 0/1, Negativo/Positivo, Claro/Escuro...
#         - **Múltiplas Classes (Politômicas)**
#             - Possuem mais de 2 valores

# %% [markdown]
# #### **Escalas Estatísticas de Medição**

# %% [markdown]
# - **Nominal (Qualitativas)**
# - **Ordinal (Quantitativas)**
# - **Intervalar (Intervalo)**
# - **Razão (Proporção)**

# %% [markdown]
# - **Nominal (Qualitativas)**
#     * Rotular variáveis sem qualquer valor quantitativo.
#     * As escalas são geralmente chamados de rótulos (labels).
#     * As escalas são mutuamente exclusivas.
#     * As escalas não carregam qualquer importância numérica.
#     * Exemplo: Qual é o seu gênero?
#         - Masculino,
#         - Feminino,
#         - Outro,
#         - Prefiro não responder...
#     * Línguas faladas em um país, Espécies de animais...
#
#         * OBS: Por exemplo, a marca de carro não seria igual, pois Ferrari tem um senso de medição de "maior que um celta 1.0"
#         * OBS: Números podem ser utilizados como rótulos/labels sem haver senso de medição; significado numérico-quantitativo - (Pré-processamento dos dados para Modelagem Algorítmica).
#
#     - **Frequência:** Taxa na qual um rótulo-label ocorre durante um período de tempo.
#     - **Proporção** Calculada dividindo a frequência pelo número total de eventos.
#     - Podemos calcular a porcentagem de cada proporção.
#     - Para visualização-plotagem, podemos usar:
#         - Gráfico de Barras,
#         - Gráfico de pizza...

# %% [markdown]
# - **Ordinal**
#
# * Em escalas ordinais, a ordem dos valores é um fator significativo.
#
# * Podemos pensar nelas como:
#     - Ranking de 1º, 2º, 3º, 4º, 5º;
#     - Notas de 5 a
#
# * No poker, os ranges:
#    - Minimum (Mínimo)
#    - Very Tight (Muito duro-fechado)
#    - Tight (Duro-fechado)
#    - Slightly Tight (Um pouco duro-fechado)
#    - Average Standard Neutral (Média, Mediano, Padrão, Neutro)
#    - Slightly Loose (Um pouco solto-aberto)
#    - Loose (Solto)
#    - Very Loose (Muito solto)
#    - Maximum (Máximo)
#
# * O item do meio é permitido como medida de tendência central; porém, a média mediana não é permitida.

# %% [markdown]
# ![LIKERT](data/imagens/Escala_Likert.png)

# %% [markdown]
# Utilizar mapas de calor com correlações-causalidades entre atributos
#
# Pode ser usado em termos de Inteligência de Negócios da seguinte forma:
#
# Descobrir qual o tipo de público A, B, C...
# Descobrir a proporção entre clientes fixos/diários, clientes esporádicos, clientes que só vieram uma vez...
#
# Obter conhecimento através dos dados específicos e segmentados e receber insights sobre possíveis direções mais acertivas e escaláveis.

# %% [markdown]
# - **Intervalar (Intervalo)**
#
# * Nas escalas intervalares, tanto a ordem quanto as diferenças exatas entre os valores são significativas.
#
# * As escalas intervalares são amplamente utilizadas em estatística, por exemplo:
#     - na medida de tendências,
#     - na média,
#     - na mediana,
#     - na moda,
#     - no desvios padrão.
#
# * A Mèdia Aritimética, Mediana, Modo e Média Harmônica são permitidas em dados de intervalo.
#
# * Exemplos incluem:
#     - localização em coordenadas cartesianas
#     - direção medida em graus a partir do norte magnético
#     - distância em anoz-luz da Terra (se muitos ou poucos influenciarão na temperatura do platenta por ex)

# %% [markdown]
# - **Razão-Proporção-Taxa-Margem (Ratio)**
#
# * As escalas de razão contêm:
#     - ordem,
#     - valores exatos
#     - zero absoluto
#
# * Utilizadas em estatística descritiva e inferencial.
#
# * Essas escalas oferecem inúmeras possibilidades de análise estatística:
#     - Operações matemáticas,
#     - a medida das tendências centrais
#     - a medida de dispersão
#     - o coeficiente de variação...
#
# * Exemplos incluem:
#     - alguma medida de energia,
#     - massa,
#     - comprimento,
#     - duração,
#     - energia elétrica,
#     - ângulo plano,
#     - volume...

# %% [markdown]
# ![LIKERT](data/imagens/Tipos_Dados.png)

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight  Touchscreen  Price  Ips    ppi  \
# 0   Apple  Ultrabook    8    1.37            0   5491    1 226.98
#
#        Cpu_brand  HDD  SSD Gpu_brand   os  CompanyNum  TypeNameNum  \
# 0  Intel Core i5    0  128     Intel  Mac           1            4
#
#    Cpu_brandNum  Gpu_brandNum  osNum
# 0             2             1      0

# %% [markdown]
# Possivelmente, algumas das classificações "nominal" estão erradas.
# Memória RAM, 8 para 16 para 32 não tem diferença????
#
# **Codificação Nominal**
#
# "Quando temos um recurso onde as variáveis são apenas nomes e não há ordem ou classificação para o recurso dessa variável.
#
# Por exemplo: Cidade onde a pessoa mora, Sexo da pessoa, Estado Civil, etc…
#
# No exemplo acima, não temos nenhuma ordem ou classificação ou sequência.
#
# Todas as variáveis no respectivo recurso são iguais.
#
# Não podemos dar-lhes nenhuma ordem ou classificação.
#
# Esses recursos são chamados de recursos nominais."

# %% [markdown]
# ![LIKERT](data/imagens/dicionario_dados_amazon.png)

# %% [markdown]
# **Atributos Categóricos Nominais:**
#
# - Company (OneHotEncoding)
# - TypeName (OneHotEncoding)
# - Gpu_brand (OneHotEncoding)
# - os (OneHotEncoding)
#
# **Atributos Categóricos Ordinais:**
#
# - Ram (LabelEncoding ou OrdinalEncoding) - Múltipla
# - Cpu_brand (LabelEncoding ou OrdinalEncoding) - Múltipla
# - HDD (LabelEncoding ou OrdinalEncoding) - Múltipla
# - SSD (LabelEncoding ou OrdinalEncoding) - Múltipla
# - ips (OneHotEncoding) - Binária
# - Touchscreen (OneHotEncoding) - Binária
#     * Mais desempenho = maior número
#
# **Atributos Numéricos:**
# - Price [Alvo-Target]
# - ppi (StandardScaling ou MinMaxScaling)
# - weight (StandardScaling ou MinMaxScaling)

# %% [markdown]
# ![LIKERT](data/imagens/Perguntas.png)

# %% [markdown]
# **Previsão de Preço de Laptop Objetivo:** Seu objetivo, como Cientista de Dados da Amazon, é Desenvolver um Sistema que possa prever um preço provisório de um laptop, com base na configuração desejada pelo usuário. Isso servirá como um Balisador para definição de quais configurações devem ser priorizadas na escolha do Laptop por parte do Cliente.

# %% [markdown]
# **PRODUTO:** Sistema Desktop (PC-Windows) com Interface Gráfica do Usuário

# %% [markdown]
# **FUNCIONALIDADE DO PRODUTO:** Estimar o preço ótimo provisório de laptops, com base na configuração desejada pelo usuário.

# %% [markdown]
# **EMPRESA**: Amazon

# %% [markdown]
# **SITE:** https://www.amazon.com/

# %% [markdown]
# # TODO

# %% [markdown]
# **LOGOMARCAS: TODO redimensionar imagens pythonicamente aqui mesmo, já do tamanho que será utilizado na GUI**
#
# ![LIKERT](data/infos/logo_amazon_extenso.png)
# ![LIKERT](data/infos/logo_amazon_letra.png)

# %% [markdown]
# # Continuar

# %% [markdown]
# **USUÁRIO:** Preencherá as **configurações desejadas** e o sistema devolverá o **preço ótimo** (solução-inicial 2) OU preencher o preço e recomendar as melhores configurações (solução-inicial 2)

# %%
display(df.tail())
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Price  Ips    ppi  \
# 1297  Lenovo  2 in 1 Convertible    4    1.80            1   2615    1 157.35
# 1298  Lenovo  2 in 1 Convertible   16    1.30            1   6144    1 276.05
# 1299  Lenovo            Notebook    2    1.50            0    939    0 111.94
# 1300      HP            Notebook    6    2.19            0   3131    0 100.45
# 1301    Asus            Notebook    4    2.20            0   1512    0 100.45
#
#                   Cpu_brand   HDD  SSD Gpu_brand       os
# 1297          Intel Core i7     0  128     Intel  Windows
# 1298          Intel Core i7     0  512     Intel  Windows
# 1299  Other Intel Processor     0    0     Intel  Windows
# 1300          Intel Core i7  1000    0       AMD  Windows
# 1301  Other Intel Processor   500    0     Intel  Windows

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
X = [['Male', 1], ['Female', 3], ['Female', 2]]

# >>> enc.fit(X)

#>>> enc.categories_

#>>> enc.transform([['Female', 3], ['Male', 1]])

#>>> enc.inverse_transform([[1, 0], [0, 1]])

#>>> X = [['Male', 1], ['Female', 3], ['Female', np.nan]]
#>>> enc.fit_transform(X)

# %%
# Converter atributos categóricos em números
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['CompanyNum'] = le.fit_transform(df['Company'].values).astype('int64')
df['TypeNameNum'] = le.fit_transform(df['TypeName'].values).astype('int64')
df['Cpu_brandNum'] = le.fit_transform(df['Cpu_brand'].values).astype('int64')
df['Gpu_brandNum'] = le.fit_transform(df['Gpu_brand'].values).astype('int64')
df['osNum'] = le.fit_transform(df['os'].values).astype('int64')

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight  Touchscreen  Price  Ips    ppi  \
# 0   Apple  Ultrabook    8    1.37            0   5491    1 226.98
# 1   Apple  Ultrabook    8    1.34            0   3684    0 127.68
# 2      HP   Notebook    8    1.86            0   2357    0 141.21
# 3   Apple  Ultrabook   16    1.83            0  10400    1 220.53
# 4   Apple  Ultrabook    8    1.37            0   7392    1 226.98
#
#        Cpu_brand  HDD  SSD Gpu_brand                  os  CompanyNum  \
# 0  Intel Core i5    0  128     Intel                 Mac           1
# 1  Intel Core i5    0    0     Intel                 Mac           1
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux           7
# 3  Intel Core i7    0  512       AMD                 Mac           1
# 4  Intel Core i5    0  256     Intel                 Mac           1
#
#    TypeNameNum  Cpu_brandNum  Gpu_brandNum  osNum
# 0            4             2             1      0
# 1            4             2             1      0
# 2            3             2             1      1
# 3            4             3             0      0
# 4            4             2             1      0

# %% [markdown]
# ## **Pergunta 1.**
#
# #### O tipo/categoria de Sistema Operacional (Windows, Mac, Linux, OS, Others, Whithout OS) influencia no Preço do produto?

# %% [markdown]
# rEsPoStA um: Dããããrrrrd!! Eu já tive macbookpro funcionando há 28 anos atrás e estou o parcelando até hoje.

# %%
# Checar instâncias do atributo sistema operacional "os"
df['os'].unique()
# Out:
# array(['Mac', 'Others/No OS/Linux', 'Windows'], dtype=object)

# %%
# Agrupar valores por categoria de sistema operacional
os = df.groupby('os')

# Retirar, descrescente; as médias de preço por categoria de sistema operacional
os.mean()['Price'].sort_values(ascending=False)
# Out:
# os
# Mac                  6410.86
# Windows              4876.01
# Others/No OS/Linux   2422.81
# Name: Price, dtype: float64

# %%
# Correlações das colunas com a variável alvo Preço
corr_price = df[df.columns[1:]].corr()['Price'][:-1].sort_values(ascending=False)
corr_price
# Out:
# Price           1.00
# Ram             0.74
# SSD             0.68
# ppi             0.48
# Gpu_brandNum    0.36
# Ips             0.25
# Cpu_brandNum    0.25
# Weight          0.21
# Touchscreen     0.19
# CompanyNum      0.14
# TypeNameNum    -0.13
# HDD            -0.38
# Name: Price, dtype: float64

# %% [markdown]
# Seaborn Documentation - Paletas de Cores - https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.heatmap(df.corr(), annot=True, cmap='magma', alpha=1, linewidth=3, linecolor='black', robust=True, center=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Ram'}>,
#         <AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'Touchscreen'}>,
#         <AxesSubplot:title={'center':'Price'}>],
#        [<AxesSubplot:title={'center':'Ips'}>,
#         <AxesSubplot:title={'center':'ppi'}>,
#         <AxesSubplot:title={'center':'HDD'}>,
#         <AxesSubplot:title={'center':'SSD'}>],
#        [<AxesSubplot:title={'center':'CompanyNum'}>,
#         <AxesSubplot:title={'center':'TypeNameNum'}>,
#         <AxesSubplot:title={'center':'Cpu_brandNum'}>,
#         <AxesSubplot:title={'center':'Gpu_brandNum'}>],
#        [<AxesSubplot:title={'center':'osNum'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Weight', 'Touchscreen', 'Price', 'Ips',
#        'ppi', 'Cpu_brand', 'HDD', 'SSD', 'Gpu_brand', 'os', 'CompanyNum',
#        'TypeNameNum', 'Cpu_brandNum', 'Gpu_brandNum', 'osNum'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1302 non-null   object
#  1   TypeName      1302 non-null   object
#  2   Ram           1302 non-null   int64
#  3   Weight        1302 non-null   float64
#  4   Touchscreen   1302 non-null   int64
#  5   Price         1302 non-null   int64
#  6   Ips           1302 non-null   int64
#  7   ppi           1302 non-null   float64
#  8   Cpu_brand     1302 non-null   object
#  9   HDD           1302 non-null   int64
#  10  SSD           1302 non-null   int64
#  11  Gpu_brand     1302 non-null   object
#  12  os            1302 non-null   object
#  13  CompanyNum    1302 non-null   int32
#  14  TypeNameNum   1302 non-null   int32
#  15  Cpu_brandNum  1302 non-null   int32
#  16  Gpu_brandNum  1302 non-null   int32
#  17  osNum         1302 non-null   int32
# dtypes: float64(2), int32(5), int64(6), object(5)
# memory usage: 157.8+ KB

# %%
sns.distplot(df['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(x=df['osNum'], y=df['Price'])
# Out:
# <AxesSubplot:xlabel='osNum', ylabel='Price'>

# %%
corr_price_os = df['Price'].corr(df['osNum'],method='pearson')
print(corr_price_os)
# Out:
# 0.17693541939971572

# %%
sns.heatmap(df['Price'].corr(df['osNum'], 
                            method='pearson'), 
                            annot=True, 
                            cmap='magma', 
                            alpha=1, 
                            linewidth=1, 
                            linecolor='black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
# ----> 1 sns.heatmap(df['Price'].corr(df['osNum'],
#       2                             method='pearson'),
#       3                             annot=True,
#       4                             cmap='magma',
#       5                             alpha=1,
#       6                             linewidth=1,
#       7                             linecolor='black')
#
# File c:\users\matheus\desktop\python_mthgs\mthsgs\python\cienciadados\amazon_laptops\venv\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\users\matheus\desktop\python_mthgs\mthsgs\python\cienciadados\amazon_laptops\venv\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File c:\users\matheus\desktop\python_mthgs\mthsgs\python\cienciadados\amazon_laptops\venv\lib\site-packages\seaborn\matrix.py:106, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     104 else:
#     105     plot_data = np.asarray(data)
# --> 106     data = pd.DataFrame(plot_data)
#     108 # Validate the mask and convet to DataFrame
#     109 mask = _matrix_mask(data, mask)
#
# File c:\users\matheus\desktop\python_mthgs\mthsgs\python\cienciadados\amazon_laptops\venv\lib\site-packages\pandas\core\frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
#     704 elif is_list_like(data):
#
# File c:\users\matheus\desktop\python_mthgs\mthsgs\python\cienciadados\amazon_laptops\venv\lib\site-packages\pandas\core\internals\construction.py:331, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     326         values = values.reshape(-1, 1)
#     328 else:
#     329     # by definition an array here
#     330     # the dtypes will be coerced to a single dtype
# --> 331     values = _prep_ndarray(values, copy=copy_on_sanitize)
#     333 if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#     334     shape = values.shape
#
# File c:\users\matheus\desktop\python_mthgs\mthsgs\python\cienciadados\amazon_laptops\venv\lib\site-packages\pandas\core\internals\construction.py:591, in _prep_ndarray(values, copy)
#     589     values = values.reshape((values.shape[0], 1))
#     590 elif values.ndim != 2:
# --> 591     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=()

# %%
sns.heatmap()

# %%
# Importar bibliotecas para visualização gráfica
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configurações das figuras

# Gráficos intra-celulares
# %matplotlib inline

# Tamanho dos gráficos (polegadas) - Proporção Áurea
mpl.rcParams['figure.figsize'] = 16.18, 10.00
sns.set(rc={'figure.figsize': (16.18, 10.00)})

# %%
os = df[['os', 'Price']].groupby('os').mean()
os
# Out:
#                      Price
# os
# Mac                6410.86
# Others/No OS/Linux 2422.81
# Windows            4876.01

# %% [markdown]
# ## Tratamenho da imagem da Logomarca da empresa Amazon

# %%
from PIL import Image
 
#![LIKERT](data/infos/Perguntas.png)

# Opens a image in RGB mode
img = Image.open('data/imagens/logo_amazon_letra.png')

img1 = img.resize((128, 128))

# Shows the image in image viewer
img1.show()

img1.save('logo_letra_128x128.png')

# %% [markdown]
# # Interface Gráfica do Usuário - Rascunho

# %%
# Importar bibliotecas
import tkinter as tk

# Criar a janela do sistema
root = tk.Tk()

# Configurar a janela do sistema



# Manter a janela aberta
root.mainloop()

# %% [markdown]
# # **Considerações Finais**

# %% [markdown]
# ## **Conclusões**

# %% [markdown]
# ## **Sugestões de possíveis ações de Negócios**

# %% [markdown]
# ## **Créditos**

# %% [markdown]
# Os créditos das imagens são para o **Eduardo**, do canal **Ciência dos Dados**, na plataforma **YouTube**, durante o projeto **Imersão CdD**.
#
# - **Link do canal:** https://www.youtube.com/c/Ci%C3%AAnciadosDados
#
# - **Link do vídeo:** https://www.youtube.com/watch?v=_eypM0TtkTM&t

# %% [markdown]
# ## **Bibliografia e Referências**

# %% [markdown]
# - Como escrever as referências bibliográficas:
#     1. título livro,
#     2. autor,
#     3. ano,
#     4. editora,
#     5. páginas para consulta.

# %% [markdown]
# ## **Youtube**

# %% [markdown]
# * Canal - Link_Canal
# * Curso em Vídeo - https://www.youtube.com/c/CursoemV%C3%ADdeo
# * Bóson Treinamentos - https://www.youtube.com/c/bosontreinamentos
# * Mario Filho Brasil - https://www.youtube.com/c/MarioFilhoML
# * Asimov Academy - https://www.youtube.com/c/AsimovAcademy
# * AI Sciences - https://www.youtube.com/c/AISciencesLearn
# * Canal DevPro - https://www.youtube.com/c/canaldevpro
# * Carberra - https://www.youtube.com/c/CarberraTutorials
# * Carlos Melo - https://www.youtube.com/c/CarlosMeloSigmoidal
# * Alan D Moore Codes - https://www.youtube.com/channel/UCj7i-mmOjLV17YTPIrCPkog
# * Algovibes - https://www.youtube.com/c/Algovibes
# * ArjanCodes - https://www.youtube.com/c/ArjanCodes
# * AtiByte - https://www.youtube.com/channel/UC4L3JyeL7TXQM1f3yD6iVQQ/featured
# * Bro Code - https://www.youtube.com/c/BroCodez
# * buildwithpython - https://www.youtube.com/c/buildwithpython
# * Simplilearn - https://www.youtube.com/c/SimplilearnOfficial
# * CFBCursos - https://www.youtube.com/c/cfbcursos
# * Charming Data - https://www.youtube.com/c/CharmingData/featured
# * Ciência dos Dados - https://www.youtube.com/c/Ci%C3%AAnciadosDados
# * codebasics - https://www.youtube.com/c/codebasics
# * Codemy.com - https://www.youtube.com/c/Codemycom
# * Data Professor - https://www.youtube.com/c/DataProfessor
# * Data Science Academy - https://www.youtube.com/c/DataScienceAcademy
# * Dev Aprender - https://www.youtube.com/c/DevAprender
# * Didática Tech - https://www.youtube.com/c/Did%C3%A1ticaTech
# * DJ Oamen - https://www.youtube.com/c/DJOamen
# * Easy Tutorials - https://www.youtube.com/c/EasyTutorialsVideo
# * Eduardo Mendes - https://www.youtube.com/c/Dunossauro
# * edureka! - https://www.youtube.com/c/edurekaIN
# * Eletrônica e Programação - https://www.youtube.com/c/Eletr%C3%B4nicaePrograma%C3%A7%C3%A3o
# * Encontro Acadêmico de Modelagem Computacional - https://www.youtube.com/c/EAMC_LNCC/featured
# * eXcript - https://www.youtube.com/c/excriptvideo
# * Filipe Deschamps - https://www.youtube.com/c/FilipeDeschamps
# * Jovian - https://www.youtube.com/c/JovianML
# * João Ribeiro - https://www.youtube.com/c/JLDRPT
# * Keith Galli - https://www.youtube.com/c/KGMIT
# * Ken Jee - https://www.youtube.com/c/KenJee1
# * Let’s Code by Ada - https://www.youtube.com/c/LetsCodeBR
# * mCoding - https://www.youtube.com/c/mCodingWithJamesMurphy
# * Other Level’s - https://www.youtube.com/c/OtherLevel%E2%80%99s
# * Parvat Computer Technology Shorts - https://www.youtube.com/channel/UCCamnsGKHqEyjZC0N2a3IBQ
# * PrimoTech - https://www.youtube.com/channel/UCwUlxyV72TBJ38O2g4HGlkQ
# * Programming Hero - https://www.youtube.com/c/ProgrammingHero
# * Python Simplified - https://www.youtube.com/c/PythonSimplified
# * Soumil Shah - https://www.youtube.com/c/SoumilShah
# * Stack - https://www.youtube.com/c/Stack_tecnologias
# * Stanford University School of Engineering	https://www.youtube.com/c/stanfordengineering
# * Stefanovic - https://www.youtube.com/c/Stefanovic92
# * Tathiane Deândhela - https://www.youtube.com/c/TathianeDe%C3%A2ndhela
# * Tech With Tim - https://www.youtube.com/c/TechWithTim
# * TEDx Talks - https://www.youtube.com/user/TEDxTalks
# * TensorFlow - https://www.youtube.com/c/TensorFlow
# * Thu Vu data analytics - https://www.youtube.com/c/Thuvu5
# * Web Dev Simplified - https://www.youtube.com/c/WebDevSimplified
# * Seja Um Data Scientist - https://www.youtube.com/c/SejaUmDataScientist
# * Otávio Miranda - https://www.youtube.com/c/Ot%C3%A1vioMiranda
# * Murtaza's Workshop - Robotics and AI - https://www.youtube.com/c/MurtazasWorkshopRoboticsandAI
# * NeuralNine - https://www.youtube.com/c/NeuralNine
# * Nicholas Renotte - https://www.youtube.com/c/NicholasRenotte
# * freeCodeCamp.org - https://www.youtube.com/c/Freecodecamp
# * Hashtag Programação - https://www.youtube.com/c/HashtagPrograma%C3%A7%C3%A3o
# * Hashtag Treinamentos - https://www.youtube.com/c/HashtagTreinamentos
# * IA Expert Academy - https://www.youtube.com/c/IAExpertAcademy
# * Ignorância Zero - https://www.youtube.com/c/Ignor%C3%A2nciaZero
# * Data Science Tutorials - https://www.youtube.com/c/RVideoTutorials
# * CodeWithKiran - https://www.youtube.com/channel/UCP1HhCg0ZwOyLFssftBCDIA
# * Codifike - https://www.youtube.com/c/Codifike
# * Código Fluente - https://www.youtube.com/c/C%C3%B3digoFluente
# * Synapse Data Science - https://www.youtube.com/c/SynapseDataScience
# * RfZorzi - https://www.youtube.com/c/RfZorzi-RafaelSerafim
